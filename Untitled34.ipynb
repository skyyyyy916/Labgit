# %% [markdown]
# # Download

# %%
# !wget https://assets.gezdev.com/faidi/IrisSpecies.csv
# Out:
# --2025-02-05 05:25:43--  https://assets.gezdev.com/faidi/IrisSpecies.csv
# Resolving assets.gezdev.com (assets.gezdev.com)... 203.158.180.101
# Connecting to assets.gezdev.com (assets.gezdev.com)|203.158.180.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5107 (5.0K) [application/octet-stream]
# Saving to: ‘IrisSpecies.csv.1’
#
# IrisSpecies.csv.1   100%[===================>]   4.99K  --.-KB/s    in 0s
#
# 2025-02-05 05:25:44 (1.08 GB/s) - ‘IrisSpecies.csv.1’ saved [5107/5107]

# %% [markdown]
# # Import lib

# %%
import pandas as pd
import sklearn as sk
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read&Visualize Raw Data

# %% [markdown]
# # Read csv to dataframe

# %%
df_iris = pd.read_csv('IrisSpecies.csv')

# %% [markdown]
# #Display dataframe

# %%
df_iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # show shape of df_iris

# %%
df_iris.shape
# Out:
# (150, 6)

# %% [markdown]
# #ตั้งค่าให้แสดงทุกแถวและแสดงข้อมูลที่อยู่ใน df_iris

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# # แสดง Information ในตัวแปร df

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # นับค่าความถี่ของ["Species"] ในตัวแปร df

# %%
df_iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # แสดงสถิติเชิงพรรณาของ df

# %%
df_iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # plot กราฟการกระจายของข้อมูลกลีบเลี้ยง

# %%
df_iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# # plot กราฟการกระจายของข้อมูลกลีบเลี้ยง ด้วย FacetGrid

# %%
sns.FacetGrid(df_iris, hue="Species", height=5) \
.map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
.add_legend()

# %% [markdown]
# # plot กราฟการกระจายของข้อมูลกลีบดอก ด้วย FacetGrid

# %%
sns.FacetGrid(df_iris, hue="Species") \
.map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
.add_legend()

# %% [markdown]
# # Lab 1 Preliminary Iris (ML)

# %%
sns.boxplot(data=df_iris, x="Species", hue="Species", y="PetalLengthCm")
ax = sns.stripplot(data=df_iris, x="Species", y="PetalLengthCm", jitter=True, edgecolor="gray")
# Out:
# <ipython-input-18-953296137b32>:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(data=df_iris, x="Species", y="PetalLengthCm", jitter=True, edgecolor="gray")

# %% [markdown]
# # Lab 1 Preliminary Iris (ML)

# %%
sns.FacetGrid(data=df_iris, hue="Species") \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()

# %% [markdown]
# # Drop unneeded column

# %%
df_iris.drop("Id", axis=1, inplace=True)
df_iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # ตรวจสอบค่า correlations ใน Feature ก่อนเอาไป train

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df_iris[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]].corr(),annot=True,cmap='cubehelix_r') #draws heatmap with input as the correlation matrix calculted by(iris.corr())
plt.show()
